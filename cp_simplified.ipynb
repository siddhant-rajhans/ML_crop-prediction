# %%
# Import essential libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier  # Consider classification model
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix

# %%
data = pd.read_csv("cpdata.csv")

# %%
data2 = pd.read_csv("DATASET.csv")

# %%
data2.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
crop2 = data2.label.unique()
crop2
# Out:
# array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %%
data
# Out:
#       temperature   humidity        ph    rainfall       label
# 0       20.879744  82.002744  6.502985  202.935536        rice
# 1       21.770462  80.319644  7.038096  226.655537        rice
# 2       23.004459  82.320763  7.840207  263.964248        rice
# 3       26.491096  80.158363  6.980401  242.864034        rice
# 4       20.130175  81.604873  7.628473  262.717340        rice
# ...           ...        ...       ...         ...         ...
# 3095    25.287846  89.636679  6.765095   58.286977  watermelon
# 3096    26.638386  84.695469  6.189214   48.324286  watermelon
# 3097    25.331045  84.305338  6.904242   41.532187  watermelon
# 3098    26.897502  83.892415  6.463271   43.971937  watermelon
# 3099    26.986037  89.413849  6.260839   58.548767  watermelon
#
# [3100 rows x 5 columns]

# %%
if not pd.api.types.is_numeric_dtype(data['label']):
    data = pd.get_dummies(data, columns=['label'], drop_first=True)

# %%
if not pd.api.types.is_numeric_dtype(data2['label']):
    data2 = pd.get_dummies(data2, columns=['label'], drop_first=True)

# %%
X2 = data2.iloc[:, :-1]  # Features
y2 = data2.iloc[:, -1]

# %%
X = data.iloc[:, :-1]  # Features
y = data.iloc[:, -1]

# %%
data2.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall  label_banana  \
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536         False
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537         False
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248         False
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034         False
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340         False
#
#    label_blackgram  label_chickpea  ...  label_mango  label_mothbeans  \
# 0            False           False  ...        False            False
# 1            False           False  ...        False            False
# 2            False           False  ...        False            False
# 3            False           False  ...        False            False
# 4            False           False  ...        False            False
#
#    label_mungbean  label_muskmelon  label_orange  label_papaya  \
# ...

# %%
# Define crop labels (modify these based on your actual labels)
crops = ['wheat', 'mungbean', 'Tea', 'millet', 'maize', 'lentil', 'jute', 'cofee',
        'cotton', 'ground nut', 'peas', 'rubber', 'sugarcane', 'tobacco',
        'kidney beans', 'moth beans', 'coconut', 'blackgram', 'adzuki beans',
        'pigeon peas', 'chick peas', 'banana', 'grapes', 'apple', 'mango',
        'muskmelon', 'orange', 'papaya', 'watermelon', 'pomegranate']

# %%
crop2
# Out:
# array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %%
len(crops)
# Out:
# 30

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, test_size=0.3)

# %%
X_train2
# Out:
#         N    P    K  temperature   humidity        ph    rainfall  \
# 889    12   80   19    21.910410  65.216625  5.962001   36.102114
# 1680   32   25    9    10.356096  93.756520  7.796034  101.145695
# 1795   42   59   55    40.102077  94.351102  6.979102  149.119999
# 1634   16    7    8    22.791968  90.609019  6.420457  116.508407
# 2087   71   54   35    26.639525  70.957060  7.311077  199.335574
# ...   ...  ...  ...          ...        ...       ...         ...
# 1018  100   76   45    25.567030  75.940677  5.590236  102.786772
# 1219    4  136  204    29.937076  81.777135  5.898944   65.522793
# 731    25   65   21    33.863512  68.592323  6.880246   69.244641
# 1624   33   14    8    21.032001  92.964197  7.684420  110.682394
# 277    31   76   82    20.824845  17.850571  7.599280   79.205092
#
#       label_banana  label_blackgram  label_chickpea  ...  label_maize  \
# 889          False            False           False  ...        False
# ...

# %%
y_train2
# Out:
# 889     False
# 1680    False
# 1795    False
# 1634    False
# 2087    False
#         ...
# 1018    False
# 1219    False
# 731     False
# 1624    False
# 277     False
# Name: label_watermelon, Length: 1540, dtype: bool

# %%
scaler = StandardScaler()
X_train2 = scaler.fit_transform(X_train2)
X_test2 = scaler.transform(X_test2)

# %%
model = DecisionTreeClassifier()
model.fit(X_train2, y_train2)
# Out:
# DecisionTreeClassifier()

# %%
# Import libraries for SVM and Random Forest
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

# Create SVM and Random Forest models
svm_model = SVC()
rf_model = RandomForestClassifier()

# Fit the models
svm_model.fit(X_train2, y_train2)
rf_model.fit(X_train2, y_train2)

# Evaluate model performance on test data
svm_accuracy = accuracy_score(y_test2, svm_model.predict(X_test2)) * 100
rf_accuracy = accuracy_score(y_test2, rf_model.predict(X_test2)) * 100

print("SVM model accuracy:", svm_accuracy)
print("Random Forest model accuracy:", rf_accuracy)
# Out:
# SVM model accuracy: 100.0
# Random Forest model accuracy: 100.0

# %%
# Calculate precision, recall, F1, and confusion matrix for SVM model
svm_metrics = {
    'Precision': precision_score(y_test2, svm_model.predict(X_test2)),
    'Recall': recall_score(y_test2, svm_model.predict(X_test2)),
    'F1 Score': f1_score(y_test2, svm_model.predict(X_test2)),
    'Confusion Matrix': confusion_matrix(y_test2, svm_model.predict(X_test2))
}

# Calculate precision, recall, F1, and confusion matrix for Random Forest model
rf_metrics = {
    'Precision': precision_score(y_test2, rf_model.predict(X_test2)),
    'Recall': recall_score(y_test2, rf_model.predict(X_test2)),
    'F1 Score': f1_score(y_test2, rf_model.predict(X_test2)),
    'Confusion Matrix': confusion_matrix(y_test2, rf_model.predict(X_test2))
}

# Create DataFrames for SVM and Random Forest metrics
svm_metrics_df = pd.DataFrame.from_dict(svm_metrics, orient='index', columns=['SVM Model'])
rf_metrics_df = pd.DataFrame.from_dict(rf_metrics, orient='index', columns=['Random Forest Model'])

# %%
# Function to display confusion matrix as heatmap
def plot_confusion_matrix(confusion_matrix, title):
    plt.figure(figsize=(5, 5))
    sns.heatmap(confusion_matrix, annot=True, fmt="d", cmap="Blues", cbar=False)
    plt.xlabel("Predicted Labels")
    plt.ylabel("True Labels")
    plt.title(title)
    plt.show()

# %%
display(svm_metrics_df)
display(rf_metrics_df)
# Out:
#                             SVM Model
# Precision                         1.0
# Recall                            1.0
# F1 Score                          1.0
# Confusion Matrix  [[630, 0], [0, 30]]
#                   Random Forest Model
# Precision                         1.0
# Recall                            1.0
# F1 Score                          1.0
# Confusion Matrix  [[630, 0], [0, 30]]

# %%
display(rf_metrics_df)
# Out:
#                   Random Forest Model
# Precision                         1.0
# Recall                            1.0
# F1 Score                          1.0
# Confusion Matrix  [[630, 0], [0, 30]]

# %%
# Display confusion matrices as heatmaps
#plot_confusion_matrix(svm_cm, "SVM Confusion Matrix")

# %%
#plot_confusion_matrix(rf_cm, "Random Forest Confusion Matrix")

# %%
# Evaluate model accuracy on unseen data
accuracy = accuracy_score(y_test2, model.predict(X_test2)) * 100
print("Model accuracy:", accuracy)
# Out:
# Model accuracy: 100.0

# %%
import joblib
# Save models
joblib.dump(svm_model, 'models2/svm_model.pkl')
joblib.dump(rf_model, 'models2/rf_model.pkl')
joblib.dump(model, 'models2/dt_model.pkl')
# Out:
# ['models2/dt_model.pkl']

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Select a random sample from the test set (replace 1 with your desired sample size)
random_index = np.random.randint(0, len(X_test2) - 1)
random_data = X_test2[random_index].reshape(1, -1)

# %%
# Scale the random data using the same scaler
random_data_scaled = scaler.transform(random_data)

# %%
# Make prediction on the random data
prediction = model.predict(random_data_scaled)[0]  # Get the first element

# %%
# Print the predicted crop based on the index
print("Predicted crop:", crops[prediction])
# Out:
# Predicted crop: wheat

# %%
# Show the first row of the data (assuming informative features)
print("\nData preview (first row):")
display(data.head(1))
# Out:
# Data preview (first row):
#    temperature   humidity        ph    rainfall  label_Black gram  \
# 0    20.879744  82.002744  6.502985  202.935536             False
#
#    label_Chickpea  label_Coconut  label_Coffee  label_Cotton  \
# 0           False          False         False         False
#
#    label_Ground Nut  ...  label_maize  label_mango  label_millet  \
# 0             False  ...        False        False         False
#
#    label_muskmelon  label_orange  label_papaya  label_pomegranate  label_rice  \
# 0            False         False         False              False        True
#
#    label_watermelon  label_wheat
# 0             False        False
#
# [1 rows x 34 columns]

# %%
# **Prediction using randomly selected data**

# Select a random sample from the test set (replace 1 with your desired sample size)
random_index = np.random.randint(0, len(X_test) - 1)
random_data = X_test[random_index].reshape(1, -1)

# Scale the random data using the same scaler
random_data_scaled = scaler.transform(random_data)
# Make prediction on the random data
prediction = model.predict(random_data_scaled)[0]  # Get the first element
# Print the predicted crop based on the index
print("\nPredicted crop:", crops[prediction])
# Out:
# Predicted crop: wheat
